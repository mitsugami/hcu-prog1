# %% [markdown]
# #プログラミングⅠ演習 第6回課題
#
# * 第1回～第5回で学んだ内容の復習し，それらを組合せて以下の演習を解こう．
# * これまでの重要事項をまとめた [Tips](https://colab.research.google.com/drive/1lzOa-a_u9bkY8S6-4QPjtvmXYDhMLYp3?usp=sharing) も用意しましたので，これも学習に用いてください．

# %% [markdown]
# ---
# ###演習1
# 20人のテストの点数を格納したリスト(score)がある．この最高点・最低点・平均点を表示するプログラムを作成しよう．

# %% [markdown]
# （ちなみに，このリストは50～100の範囲のランダム値を20個生成することにより作成している．以下はそのコードですが，**これは中間まとめの範囲ではない**．ランダム値は実行のたびに異なる値となるため，生成されるリストは以下のコードのものとは一致しない．）

# %%
# ランダム値のリストを生成するためのコード．中間まとめの範囲外．
import random

scores = []
for i in range(20):
  scores.append( random.randrange(50, 100) )

print(scores)

# %% [markdown]
# **① for文を使って書いてみよう**

# %%
scores = [75, 90, 83, 71, 67, 90, 66, 98, 67, 59, 73, 51, 97, 83, 52, 65, 81, 98, 62, 58]

# ここに max_score, min_score, ave_score に値を代入する処理を書いてください




print('最高点は', max_score, 'です' )
print('最低点は', min_score, 'です' )
print('平均点は', ave_score, 'です' )

# %% [markdown]
# **② for文は用いず，リスト用の組み込み関数（ sum(), len(), max(), min() ）を使って書いてみよう**

# %%
scores = [75, 90, 83, 71, 67, 90, 66, 98, 67, 59, 73, 51, 97, 83, 52, 65, 81, 98, 62, 58]

# ここに max_score, min_score, ave_score に値を代入する処理を書いてください




print('最高点は', max_score, 'です' )
print('最低点は', min_score, 'です' )
print('平均点は', ave_score, 'です' )

# %% [markdown]
# ###演習2
# 'abcd-efg' のように途中に1個のハイフンを含む文字列を引数として受け取り，ハイフン前の文字列（この例なら'abcd'）とハイフン後の文字列（'efg'）を戻り値とする（つまり戻り値が2つ）関数 str_divide() を作成しよう．

# %%
moji = 'abcd-efg'

# ここに関数 str_divide の定義を記述しよう




mae, ato = str_divide(moji)
print( mae, ato )

# %% [markdown]
# ###演習3
# 関数が呼ばれるたびに引数として与えられる1つの数値を受け取り，その累積和を戻り値として返す関数 accum() を作成しよう．

# %%
accum_value = 0

# ここに関数 accum の定義を記述しよう




print( accum(1) )
print( accum(2) )
print( accum(3) )
print( accum(4) )
print( accum(5) )
print( accum(-10) )
print( accum(6) )

# %% [markdown]
# ###演習4
# 繰り返しキーボードから入力される数値の累積和を表示するプログラムを作成しよう．なお，キーボード入力で end と入力されるとプログラムは終了するものとし，数値・end以外が入力されることは無いものとする．
# 演習3の accum() 関数を利用すること．
#
# ```
# 数値を入力してください（終了したい場合は End と入力） > 1
# 1
# 数値を入力してください（終了したい場合は End と入力） > 2
# 3
# 数値を入力してください（終了したい場合は End と入力） > 3
# 6
# 数値を入力してください（終了したい場合は End と入力） > 4
# 10
# 数値を入力してください（終了したい場合は End と入力） > 5
# 15
# 数値を入力してください（終了したい場合は End と入力） > -10
# 5
# 数値を入力してください（終了したい場合は End と入力） > 6
# 11
# 数値を入力してください（終了したい場合は End と入力） > end
# ```

# %%
# ここにコードを記述しよう

# %% [markdown]
# ---
# 以上の課題が完了したら，以下の作業を行うこと．
#
# 1. メニューの「ファイル」-「ドライブにコピーを保存」を選択し，自分のGoogleドライブに課題を保存する．
# 2. メニューの「ファイル」-「ダウンロード」-「.ipynbファイルをダウンロード」を選択し，提出用の課題ファイル(kadai06.ipynb)をダウンロードする．
# 3. ファイル名を「(学籍番号)-06.ipynb」(学籍番号が2120999なら 2120999-06.ipynb）に変更し，WebClassに提出．
